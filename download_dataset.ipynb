# %%
from bs4 import BeautifulSoup
import urllib.request
from pytube import YouTube
import re
import os
import sys
import urllib
import urllib.request
try:
    from urllib.request import Request, urlopen  # Python 3
except:
    from urllib2 import Request, urlopen 
    
    
    
def download_youtube_videos(class_name, queries, main_path):
    user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
    headers = { 'User-Agent' : user_agent }
    data = None
    queries = [q.replace(" ", "+") for q in queries]
    base_url = "https://www.youtube.com/results?search_query=" 
    urls = []
    for q in queries:
        req = urllib.request.Request(base_url + q, data, headers)
        with urllib.request.urlopen(req) as response:
            the_page = response.read()
        soup = BeautifulSoup(the_page)
        mydivs = soup.findAll("div", { "id" : "results" })[0]
        a = mydivs.find_all("a")
        b = filter(lambda x: "watch" in x, map(lambda x: x.get("href", -1), a))
        urls += ["https://www.youtube.com"+x for x in list(b)]
    for url in urls:
        filename = main_path + class_name + "/tmp_1"
        cmd = "rm " + filename
        os.system(cmd)
        
        yt = YouTube(url)

        try:
            video = yt.get('mp4', '720p')
        except:
            video = yt.get('mp4')
        video.download(filename)
        
        
        outputfile = main_path + class_name + "/" + url.split("?v=")[-1] + "/"
        cmd = "mkdir " + outputfile
        os.system(cmd)
        cmd='ffmpeg -i '+filename+' -r 1 -s 224x224 ' + outputfile + 'f_%04d.jpg'
        os.system(cmd)
        sys.stdout.write("Video downloaded at: "+ outputfile + "\n")
        
        
        
         
    
def process_video_queries(main_path, classes_dict):
    
    for class_name, queries in list(classes_dict.items()):
        cmd = "mkdir " + main_path + class_name + "/"
        os.system(cmd)
    
        sys.stdout.write("Processing " + class_name + "\n")
        download_youtube_videos(class_name, queries, main_path)

# %%
def process_images_queries(main_path, classes_dict):
    for class_name, queries in list(classes_dict.items()):
        cmd = "mkdir " + main_path + class_name + "/"
        os.system(cmd)
        queries = [q.replace(" ", "+") for q in queries]
        sys.stdout.write("Processing " + class_name + "\n")
        download_google_pics(class_name, queries, main_path)
        download_flickr_pics(class_name, queries, main_path)
        

def download_flickr_pics(class_name, queries, main_path):
    user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
    headers = { 'User-Agent' : user_agent }
    data = None
    base_url = "https://www.flickr.com/search/?orientation=landscape%2Csquare%2Cpanorama&text="
    urls = []
    outputfile = main_path + class_name + "/"
    for q in queries:
        req = urllib.request.Request(base_url + q, data, headers)
        with urllib.request.urlopen(req) as response:
            the_page = response.read()
        soup = BeautifulSoup(the_page)
        m = list(soup.findAll("div", {"class":"view photo-list-view requiredToShowOnServer"})[0])
        urls += [re.search("url\(//([\w\./])+",str(t)).group().replace("url(//", "http://") for t in m]
    for url in urls:
        urllib.request.urlretrieve(url, outputfile + url.split("/")[-1])
        

def get_url_img(t):
    r = re.search("url\(//([\w\./])+",str(t))
    if r != None:
        return r.group().replace("url(//", "http://")
    else:
        return -1
    
def download_google_pics(class_name, queries, main_path):
    user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
    headers = { 'User-Agent' : user_agent }
    data = None
    base_url = "https://www.google.com/search?source=lnms&tbm=isch&sa=X&q="

    urls = []
    outputfile = main_path + class_name + "/"
    for q in queries:
        req = urllib.request.Request(base_url + q, data, headers)
        with urllib.request.urlopen(req) as response:
            the_page = response.read()
        soup = BeautifulSoup(the_page)
        m = soup.findAll("a")
        urls += [t.find("img")["src"] for t in m if t.find("img") != None]
    for url in urls:
        urllib.request.urlretrieve(url, outputfile + url.split("?q=tbn:")[-1])

# %%
q_d = {"Cocacola": ["cocacola ads", "cocacola commercial"],
       "Nike": ["nike ad", "nike reviews"]
      }

# %%
process_images_queries( "/Users/francescoferrari/Downloads/test/", q_d)
# Out:
# Processing Cocacola
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))
# Processing Nike

# %%
process_video_queries( "/Users/francescoferrari/Downloads/test/", q_d)

# %%
url = "https://www.instagram.com/explore/tags/cocacola/"

# %%
user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
headers = { 'User-Agent' : user_agent }
data = None
base_url = "https://www.instagram.com/explore/tags/cocacola/"

urls = []
req = urllib.request.Request(base_url , data, headers)
with urllib.request.urlopen(req) as response:
    the_page = response.read()
soup = BeautifulSoup(the_page)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en" class="no-js lt-ie9 lt-ie8 lt-ie7 not-logged-in "> <![endif]-->
# <!--[if IE 7]>         <html lang="en" class="no-js lt-ie9 lt-ie8 not-logged-in "> <![endif]-->
# <!--[if IE 8]>         <html lang="en" class="no-js lt-ie9 not-logged-in "> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js not-logged-in " lang="en"> <!--<![endif]-->
# <head><meta charset="utf-8">
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <title>
# #cocacola • Instagram photos and videos
# </title>
# <script type="text/javascript">
#   WebFontConfig = {
#     custom: {
#       families: ['proxima-nova:n3,n4,n6,n7'],
#     }
#   };
# </script>
# <script async="" src="/static/scripts/webfont.js/c0456c81549b.js" type="text/javascript"></script>
# <style type="text/css">
#   /* @license
#    * MyFonts Webfont Build ID 2164953, 2012-03-23T23:06:30-0400
#    *
#    * The fonts listed in this notice are subject to the End User License
#    * Agreement(s) entered into by the website owner. All other parties are
#    * explicitly restricted from using the Licensed Webfonts(s).
#    *
#    * You may obtain a valid license at the URLs below.
#    *
#    ** Webfont: Proxima Nova Light by Mark Simonson
#    * URL: http://www.myfonts.com/fonts/marksimonson/proxima-nova/light/
#    * Licensed pageviews: unlimited
#    *
#    * Webfont: Proxima Nova Regular by Mark Simonson
#    * URL: http://www.myfonts.com/fonts/marksimonson/proxima-nova/regular/
#    * Licensed pageviews: unlimited
#    *
#    * Webfont: Proxima Nova Semibold by Mark Simonson
#    * URL: http://www.myfonts.com/fonts/marksimonson/proxima-nova/semibold/
#    * Licensed pageviews: unlimited
#    ** Webfont: Proxima Nova Bold Italic by Mark Simonson
#    * URL: http://www.myfonts.com/fonts/marksimonson/proxima-nova/bold-it/
#    * Licensed pageviews: unlimited
#    *
#    * Webfont: Proxima Nova Bold by Mark Simonson
#    * URL: http://www.myfonts.com/fonts/marksimonson/proxima-nova/bold/
#    * Licensed pageviews: unlimited
#    *
#    * Webfont: Proxima Nova Italic by Mark Simonson
#    * URL: http://www.myfonts.com/fonts/marksimonson/proxima-nova/regular-it/
#    * Licensed pageviews: unlimited
#    *
#    *
#    * License: http://www.myfonts.com/viewlicense?type=web&buildid=2164953
#    * Webfonts copyright: Copyright (c) Mark Simonson, 2005. All rights reserved.
#    *
#    * (c) 2012 Bitstream Inc
#    */@font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-bold-webfont.eot/115b1f7f9c04.eot');
#     src: url(' /static/webfonts/proximanova-bold-webfont.eot/115b1f7f9c04.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-bold-webfont.woff/618250d25a4d.woff') format("woff"),
#       url(' /static/webfonts/proximanova-bold-webfont.ttf/646346e03084.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-bold-webfont.svg/e55a9d6051e8.svg#ProximaNovaBold') format("svg");
#     font-weight: bold;
#     font-style: normal;
#     unicode-range: U+0000-00FF, U+0180-FFFF;
#   }
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-bold-latin-a-webfont.eot/78bfc2a26356.eot');
#     src: url(' /static/webfonts/proximanova-bold-latin-a-webfont.eot/78bfc2a26356.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-bold-latin-a-webfont.woff/2db359b9065d.woff') format("woff"),
#       url(' /static/webfonts/proximanova-bold-latin-a-webfont.ttf/5ae1219dca10.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-bold-latin-a-webfont.svg/017659bcaa88.svg#proxima_nova_rgbold') format("svg");
#     font-weight: bold;
#     font-style: normal;
#     unicode-range: U+0100-017F;
#   }
#
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-boldit-webfont.eot/1cbb869da891.eot');
#     src: url(' /static/webfonts/proximanova-boldit-webfont.eot/1cbb869da891.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-boldit-webfont.woff/b1cf049474c9.woff') format("woff"),
#       url(' /static/webfonts/proximanova-boldit-webfont.ttf/3adb020ceae3.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-boldit-webfont.svg/29948a2d3c58.svg#ProximaNovaBoldItalic') format("svg");
#     font-weight: bold;
#     font-style: italic;
#     unicode-range: U+0000-00FF, U+0180-FFFF;
#   }
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-boldit-latin-a-webfont.eot/72586d286717.eot');
#     src: url(' /static/webfonts/proximanova-boldit-latin-a-webfont.eot/72586d286717.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-boldit-latin-a-webfont.woff/ea0011f1fa31.woff') format("woff"),
#       url(' /static/webfonts/proximanova-boldit-latin-a-webfont.ttf/54abdaf3ee52.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-boldit-latin-a-webfont.svg/c4f67e496911.svg#proxima_novabold_italic') format("svg");
#     font-weight: bold;
#     font-style: italic;
#     unicode-range: U+0100-017F;
#   }@font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-reg-webfont.eot/12af77715cee.eot');
#     src: url(' /static/webfonts/proximanova-reg-webfont.eot/12af77715cee.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-reg-webfont.woff/a9a9773b8e29.woff') format("woff"),
#       url(' /static/webfonts/proximanova-reg-webfont.ttf/99e19808976a.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-reg-webfont.svg/c33d2fd56309.svg#ProximaNovaRegular') format("svg");
#     font-weight: normal;
#     font-style: normal;
#     unicode-range: U+0000-00FF, U+0180-FFFF;
#   }
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-reg-latin-a-webfont.eot/58dcfca24dc5.eot');
#     src: url(' /static/webfonts/proximanova-reg-latin-a-webfont.eot/58dcfca24dc5.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-reg-latin-a-webfont.woff/b84975dc78a8.woff') format("woff"),
#       url(' /static/webfonts/proximanova-reg-latin-a-webfont.ttf/794fcdf7d5cc.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-reg-latin-a-webfont.svg/08bad2145add.svg#proxima_nova_rgregular') format("svg");
#     font-weight: normal;
#     font-style: normal;
#     unicode-range: U+0100-017F;
#   }
#
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-regit-webfont.eot/1bbbd1312b0d.eot');
#     src: url(' /static/webfonts/proximanova-regit-webfont.eot/1bbbd1312b0d.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-regit-webfont.woff/9e306befca91.woff') format("woff"),
#       url(' /static/webfonts/proximanova-regit-webfont.ttf/4a8663684135.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-regit-webfont.svg/876278d4b189.svg#ProximaNovaRegularItalic') format("svg");
#     font-weight: normal;
#     font-style: italic;
#     unicode-range: U+0000-00FF, U+0180-FFFF;
#   }
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-regit-latin-a-webfont.eot/1442d729c835.eot');
#     src: url(' /static/webfonts/proximanova-regit-latin-a-webfont.eot/1442d729c835.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-regit-latin-a-webfont.woff/7bce76dac8b7.woff') format("woff"),
#       url(' /static/webfonts/proximanova-regit-latin-a-webfont.ttf/dfd8b0fc929b.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-regit-latin-a-webfont.svg/bb408d54ba63.svg#proxima_novaregular_italic') format("svg");
#     font-weight: normal;
#     font-style: italic;
#     unicode-range: U+0100-017F;
#   }
#
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-sbold-webfont.eot/5016edf79e1d.eot');
#     src: url(' /static/webfonts/proximanova-sbold-webfont.eot/5016edf79e1d.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-sbold-webfont.woff/615c1b06d8fa.woff') format("woff"),
#       url(' /static/webfonts/proximanova-sbold-webfont.ttf/2973bd483f7a.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-sbold-webfont.svg/868597833e49.svg#ProximaNovaSemibold') format("svg");
#     font-weight: 600;
#     font-style: normal;
#     unicode-range: U+0000-00FF, U+0180-FFFF;
#   }
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-sbold-latin-a-webfont.eot/6385b14bf318.eot');
#     src: url(' /static/webfonts/proximanova-sbold-latin-a-webfont.eot/6385b14bf318.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-sbold-latin-a-webfont.woff/0a6bfac8fce0.woff') format("woff"),
#       url(' /static/webfonts/proximanova-sbold-latin-a-webfont.ttf/6863621ed50b.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-sbold-latin-a-webfont.svg/608e88ac1050.svg#proxima_nova_ltsemibold') format("svg");
#     font-weight: 600;
#     font-style: normal;
#     unicode-range: U+0100-017F;
#   }@font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-light-webfont.eot/63c84728610f.eot');
#     src: url(' /static/webfonts/proximanova-light-webfont.eot/63c84728610f.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-light-webfont.woff/66bbe029f180.woff') format("woff"),
#       url(' /static/webfonts/proximanova-light-webfont.ttf/eb408516399b.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-light-webfont.svg/858f6a9b7ef3.svg#ProximaNovaLight') format("svg");
#     font-weight: 300;
#     font-style: normal;
#     unicode-range: U+0000-00FF, U+0180-FFFF;
#   }
#   @font-face {
#     font-family: 'proxima-nova';
#     src: url(' /static/webfonts/proximanova-light-latin-a-webfont.eot/11d79924ec61.eot');
#     src: url(' /static/webfonts/proximanova-light-latin-a-webfont.eot/11d79924ec61.eot?#iefix') format("embedded-opentype"),
#       url(' /static/webfonts/proximanova-light-latin-a-webfont.woff/bea5ea967c26.woff') format("woff"),
#       url(' /static/webfonts/proximanova-light-latin-a-webfont.ttf/3a5fa8856fd7.ttf') format("truetype"),
#       url(' /static/webfonts/proximanova-light-latin-a-webfont.svg/36736d1d0811.svg#proxima_nova_ltlight') format("svg");
#     font-weight: 300;
#     font-style: normal;
#     unicode-range: U+0100-017F;
#   }</style>
# <meta content="noimageindex" name="robots">
# <meta content="yes" name="mobile-web-app-capable">
# <meta content="#000000" name="theme-color">
# <meta content="yes" name="apple-mobile-web-app-capable">
# <meta content="black" name="apple-mobile-web-app-status-bar-style">
# <meta content="width=device-width, user-scalable=no, initial-scale=1, minimum-scale=1, maximum-scale=1" id="viewport" name="viewport">
# <script type="text/javascript">
#         (function() {
#             var docElement = document.documentElement;
#             var classRE = new RegExp('(^|\\s)no-js(\\s|$)');
#             var className = docElement.className;
#             docElement.className = className.replace(classRE, '$1js$2');
#         })();
#         </script>
# <script type="text/javascript">window._timings = {"domLoading": Date.now()}</script>
# <link href="/static/images/ico/apple-touch-icon-76x76-precomposed.png/932e4d9af891.png" rel="apple-touch-icon-precomposed" sizes="76x76">
# <link href="/static/images/ico/apple-touch-icon-120x120-precomposed.png/004705c9353f.png" rel="apple-touch-icon-precomposed" sizes="120x120">
# <link href="/static/images/ico/apple-touch-icon-152x152-precomposed.png/82467bc9bcce.png" rel="apple-touch-icon-precomposed" sizes="152x152">
# <link href="/static/images/ico/apple-touch-icon-167x167-precomposed.png/515cb4eeeeee.png" rel="apple-touch-icon-precomposed" sizes="167x167">
# <link href="/static/images/ico/apple-touch-icon-180x180-precomposed.png/94fd767f257b.png" rel="apple-touch-icon-precomposed" sizes="180x180">
# <link href="/static/images/ico/favicon-192.png/b407fa101800.png" rel="icon" sizes="192x192">
# <link color="#262626" href="/static/images/ico/favicon.svg/9d8680ab8a3c.svg" rel="mask-icon"><link href="/static/images/ico/favicon.ico/dfa85bb1fd63.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://www.instagram.com/explore/tags/cocacola/" rel="canonical"/>
# <meta content="4.9m Posts - See Instagram photos and videos from ‘cocacola’ hashtag" name="description"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/" hreflang="x-default" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=pl" hreflang="pl" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=si" hreflang="si" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=tr" hreflang="tr" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=hu" hreflang="hu" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=el" hreflang="el" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=fr" hreflang="fr" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=th" hreflang="th" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=nb" hreflang="nb" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ro" hreflang="ro" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=fr-ca" hreflang="fr-ca" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=mr" hreflang="mr" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ur" hreflang="ur" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=bg" hreflang="bg" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=cs" hreflang="cs" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ja" hreflang="ja" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=pt" hreflang="pt" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=bn" hreflang="bn" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=sv" hreflang="sv" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=kn" hreflang="kn" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=zh-cn" hreflang="zh-cn" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=de" hreflang="de" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=vi" hreflang="vi" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ms" hreflang="ms" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=zh-hk" hreflang="zh-hk" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=fi" hreflang="fi" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=sr" hreflang="sr" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=hi" hreflang="hi" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=tl" hreflang="tl" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=it" hreflang="it" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=da" hreflang="da" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=id" hreflang="id" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ml" hreflang="ml" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=en" hreflang="en" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=gu" hreflang="gu" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ru" hreflang="ru" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=te" hreflang="te" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=nl" hreflang="nl" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ko" hreflang="ko" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=pt-br" hreflang="pt-br" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ne" hreflang="ne" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=af" hreflang="af" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=uk" hreflang="uk" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=es" hreflang="es" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=zh-tw" hreflang="zh-tw" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=pa" hreflang="pa" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=hr" hreflang="hr" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=sk" hreflang="sk" rel="alternate"/>
# <link href="https://www.instagram.com/explore/tags/cocacola/?hl=ta" hreflang="ta" rel="alternate"/>
# </link></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></head><body class="">
# <span id="react-root"></span>
# <script src="/static/scripts/polyfills/es5-shim.min.js/6514c5e08593.js"></script>
# <script src="/static/scripts/polyfills/es5-sham.min.js/fc3c22cf2d67.js"></script>
# <script type="text/javascript">window._sharedData = {"display_properties_server_guess": {"viewport_width": 360, "pixel_ratio": 1.5}, "activity_counts": null, "language_code": "en", "platform": "web", "hostname": "www.instagram.com", "config": {"csrf_token": "chir9dd9nwJvElmoZpOKF0GgYdLXN1vz", "viewer": null}, "environment_switcher_visible_server_guess": true, "entry_data": {"TagPage": [{"tag": {"media": {"count": 4975072, "page_info": {"has_next_page": true, "end_cursor": "J0HWN8d-AAAAF0HWN8boAAAAFiYA"}, "nodes": [{"comments_disabled": false, "id": "1483082292095949801", "dimensions": {"height": 386, "width": 320}, "owner": {"id": "4777899753"}, "thumbnail_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/c0.33.320.320/17596593_282457418842923_73009290071244800_n.jpg", "is_video": false, "code": "BSU93ypDRvp", "date": 1491017208, "display_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596593_282457418842923_73009290071244800_n.jpg", "caption": "#propaganda #anos50 #cocacola", "comments": {"count": 0}, "likes": {"count": 0}}, {"comments_disabled": false, "id": "1483081870518222045", "dimensions": {"height": 750, "width": 750}, "owner": {"id": "648023990"}, "thumbnail_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17662163_439950186341926_7241581076013907968_n.jpg", "is_video": false, "code": "BSU9xqBD3zd", "date": 1491017157, "display_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s750x750/sh0.08/e35/17662163_439950186341926_7241581076013907968_n.jpg", "caption": "Les presento al amor de mi vida : Coca Cola \u2764\u2764\u2764\ud83d\udda4 #cocacola", "comments": {"count": 0}, "likes": {"count": 0}}, {"comments_disabled": false, "id": "1483080926362958437", "dimensions": {"height": 643, "width": 1080}, "owner": {"id": "1822194362"}, "thumbnail_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c218.0.643.643/17596077_1651927365114105_8763459414016393216_n.jpg", "is_video": false, "code": "BSU9j6tBXpl", "date": 1491017045, "display_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596077_1651927365114105_8763459414016393216_n.jpg", "caption": "\ubab0\ub791\uc774 \uc18c\ub300! \uc9d1\uacb0\uc644\ub8cc~~~\n\uc8fc\uc778\ub2d8\uc758 \uba85\uc744\ubc1b\uc544 \uc9d1\uacb0\uc644\ub8cc \ud588\uc74c\uc744\n\uc2e0!\uace0! \ud569\ub2c8\ub2f9~~~~~^^*\n\u119e\n\u119e\n\u119e\n\u119e\n\u119e\n#\ubab0\ub791\uc774 #\ub77c\uc789\ubab0\ub791\uc774 #\uc778\ud615\ubf51\uae30 #\uc778\ubf51#\ubf51\uae30\ubc29#\ucde8\ubbf8#\uc77c\uc0c1#\uc18c\ud1b5#\uc140\uc2a4\ud0c0\uadf8\ub7a8 #\uc5bc\uc2a4\ud0c0\uadf8\ub7a8 #\uccab\uc904#\uc120\ud314#\ub9de\ud314#\uadc0\uc6a4 #\ubc18\ud588\uc5b4 #\ubd88\ud1a0#\uc624\ub298#\ud5ec\uc2a4\ud0c0\uadf8\ub7a8 #\ud6c8\ub0a8#\ucf54\uce74\ucf5c\ub77c#cocacola #", "comments": {"count": 0}, "likes": {"count": 24}}, {"comments_disabled": false, "id": "1483080712629764793", "dimensions": {"height": 1350, "width": 1080}, "owner": {"id": "1046802540"}, "thumbnail_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c0.135.1080.1080/17596145_755892391234357_4223300007115096064_n.jpg", "is_video": false, "code": "BSU9gzph8K5", "date": 1491017019, "display_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596145_755892391234357_4223300007115096064_n.jpg", "caption": "#MyCuzzo #sfbayarea #backseatbesties #sf #hobbies #baseballgames #ar\u0026tpark #wheressteve #local #loveher #bestfran #crowded #selfies #instafab #instalove #instagiant #instagram #cocacola #mm #bestoftheday #bestfriends #freckles #makeup #tarte", "comments": {"count": 1}, "likes": {"count": 7}}, {"comments_disabled": false, "id": "1483080412065470087", "dimensions": {"height": 640, "width": 640}, "owner": {"id": "895392271"}, "thumbnail_src": "https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17438273_1737075543250007_2007675938459877376_n.jpg", "is_video": false, "code": "BSU9cbugJaH", "date": 14910 ...
# <script crossorigin="anonymous" src="/static/bundles/en_US_Commons.js/60d12268741a.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="/static/bundles/en_US_TagPage.js/d2c71cff047d.js" type="text/javascript"></script>
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','//connect.facebook.net/en_US/fbevents.js');
#
# fbq('init', '1425767024389221');
#
# fbq('track', 'PageView');
#
#
# </script>
# <noscript>
# </noscript>
# <script type="text/javascript">window._timings.domInteractive = Date.now()</script>
# </body>
# </html>

# %%
r = (re.search(r'<script type="text/javascript">window._sharedData = ([\^~\(\)\t @\* _\\n \'\r!?#$/\-{\w\":\s,\.}\[\]]+)',
          str(soup)).group().replace('<script type="text/javascript">window._sharedData = ',"")
          .replace("false","False").replace("true","True").replace("null", "None"))

# %%
import ast
d = ast.literal_eval(r)

# %%
results  = d["entry_data"]["TagPage"][0]["tag"]["media"]["nodes"]

# %%
results
# Out:
# [{'caption': '#Petaluma #california #cocacola',
#   'code': 'BSU97sSlYtD',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491017240,
#   'dimensions': {'height': 720, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17662719_617999468389245_893903490252800000_n.jpg',
#   'id': '1483082560154471235',
#   'is_video': False,
#   'likes': {'count': 2},
#   'owner': {'id': '4390700413'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c180.0.720.720/17662719_617999468389245_893903490252800000_n.jpg'},
#  {'caption': '#propaganda #anos50 #cocacola',
#   'code': 'BSU93ypDRvp',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491017208,
#   'dimensions': {'height': 386, 'width': 320},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596593_282457418842923_73009290071244800_n.jpg',
#   'id': '1483082292095949801',
#   'is_video': False,
#   'likes': {'count': 0},
#   'owner': {'id': '4777899753'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/c0.33.320.320/17596593_282457418842923_73009290071244800_n.jpg'},
#  {'caption': 'Les presento al amor de mi vida : Coca Cola ❤❤❤\ud83d\udda4 #cocacola',
#   'code': 'BSU9xqBD3zd',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491017157,
#   'dimensions': {'height': 750, 'width': 750},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s750x750/sh0.08/e35/17662163_439950186341926_7241581076013907968_n.jpg',
#   'id': '1483081870518222045',
#   'is_video': False,
#   'likes': {'count': 0},
#   'owner': {'id': '648023990'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17662163_439950186341926_7241581076013907968_n.jpg'},
#  {'caption': '몰랑이 소대! 집결완료~~~\n주인님의 명을받아 집결완료 했음을\n신!고! 합니당~~~~~^^*\nᆞ\nᆞ\nᆞ\nᆞ\nᆞ\n#몰랑이 #라잉몰랑이 #인형뽑기 #인뽑#뽑기방#취미#일상#소통#셀스타그램 #얼스타그램 #첫줄#선팔#맞팔#귀욤 #반했어 #불토#오늘#헬스타그램 #훈남#코카콜라#cocacola #',
#   'code': 'BSU9j6tBXpl',
#   'comments': {'count': 1},
#   'comments_disabled': False,
#   'date': 1491017045,
#   'dimensions': {'height': 643, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596077_1651927365114105_8763459414016393216_n.jpg',
#   'id': '1483080926362958437',
#   'is_video': False,
#   'likes': {'count': 26},
#   'owner': {'id': '1822194362'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c218.0.643.643/17596077_1651927365114105_8763459414016393216_n.jpg'},
#  {'caption': '#MyCuzzo #sfbayarea #backseatbesties #sf #hobbies #baseballgames #ar&tpark #wheressteve #local #loveher #bestfran #crowded #selfies #instafab #instalove #instagiant #instagram #cocacola #mm #bestoftheday #bestfriends #freckles #makeup #tarte',
#   'code': 'BSU9gzph8K5',
#   'comments': {'count': 1},
#   'comments_disabled': False,
#   'date': 1491017019,
#   'dimensions': {'height': 1350, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596145_755892391234357_4223300007115096064_n.jpg',
#   'id': '1483080712629764793',
#   'is_video': False,
#   'likes': {'count': 9},
#   'owner': {'id': '1046802540'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c0.135.1080.1080/17596145_755892391234357_4223300007115096064_n.jpg'},
#  {'caption': 'Como extrañaba la combinacion perfecta #hambueguesa #cocacola',
#   'code': 'BSU9cbugJaH',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016983,
#   'dimensions': {'height': 640, 'width': 640},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17438273_1737075543250007_2007675938459877376_n.jpg',
#   'id': '1483080412065470087',
#   'is_video': False,
#   'likes': {'count': 0},
#   'owner': {'id': '895392271'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17438273_1737075543250007_2007675938459877376_n.jpg'},
#  {'caption': 'Let me guess...Coca Cola? #doha #Hamad internationalairport#Cocacola #middleeast',
#   'code': 'BSU9XyxlKnk',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016945,
#   'dimensions': {'height': 1080, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17493414_215319518947491_3065292470955802624_n.jpg',
#   'id': '1483080093215795684',
#   'is_video': False,
#   'likes': {'count': 3},
#   'owner': {'id': '609159012'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17493414_215319518947491_3065292470955802624_n.jpg'},
#  {'caption': 'Enjoy.\n\n#cocacola#poster# canvas#tumblr#aesthetic#photography#photographer#exploretocreate#explore#picture#uk#ukig#grunge#house#lighting #vsco#vscocam#vsco\ud83d\udcf7indie#일상#일상\ud83d\udc95#데일리#フォトグラフィー#melancholy#coke',
#   'code': 'BSU9VGZjjS5',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016923,
#   'dimensions': {'height': 1350, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17332938_1444658332221812_5546864350553178112_n.jpg',
#   'id': '1483079908129125561',
#   'is_video': False,
#   'likes': {'count': 5},
#   'owner': {'id': '581733032'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/c0.135.1080.1080/17332938_1444658332221812_5546864350553178112_n.jpg'},
#  {'caption': '函館市電の谷地頭にて\n終点の手前で急な坂を下ります\n*\nHakodate Magistrate Office type 2000 / Hokkaido Pref. Japan\nShooting Date : Feb.27, 2017\n*\n#函館市電 #函館市交通局 #コカコーラ #路面電車 #ラッピング #tram #cocacola #electrictrain #railway #instarailway',
#   'code': 'BSU9Uo9jyOK',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016920,
#   'dimensions': {'height': 1080, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17662278_200148213814644_6574433184472104960_n.jpg',
#   'id': '1483079876520911754',
#   'is_video': False,
#   'likes': {'count': 8},
#   'owner': {'id': '2956638772'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17662278_200148213814644_6574433184472104960_n.jpg'},
#  {'caption': '#feedphx17 #creativehandscusine #cocacola #bellapalazzoestates #vacationrentals',
#   'code': 'BSU9FIDjV09',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016793,
#   'dimensions': {'height': 1080, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596195_678349659016766_5255425882939457536_n.jpg',
#   'id': '1483078810395827517',
#   'is_video': False,
#   'likes': {'count': 0},
#   'owner': {'id': '4045612668'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17596195_678349659016766_5255425882939457536_n.jpg'},
#  {'caption': 'What have you got planed this weekend @cocacola \n#style #fashion #oldschool #cocacola',
#   'code': 'BSU9AbAA7Yr',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016754,
#   'dimensions': {'height': 750, 'width': 750},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s750x750/sh0.08/e35/17596595_651407071713825_4582162572148473856_n.jpg',
#   'id': '1483078487140185643',
#   'is_video': False,
#   'likes': {'count': 0},
#   'owner': {'id': '2063452420'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17596595_651407071713825_4582162572148473856_n.jpg'},
#  {'caption': 'Fuimos separados el mismo año en que saliste al público, prometí volver a ti. Hoy ha sido ese día \ud83d\udc96\n#cocacola #vanilla #instagram #love',
#   'code': 'BSU89WSDxg5',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016729,
#   'dimensions': {'height': 1080, 'width': 1080},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17586923_1644115182272954_5089956744533114880_n.jpg',
#   'id': '1483078275915782201',
#   'is_video': False,
#   'likes': {'count': 1},
#   'owner': {'id': '500491742'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17586923_1644115182272954_5089956744533114880_n.jpg'},
#  {'caption': 'Early Bird Female Tickets are $3000 and will be available as of tomorrow evening (Saturday April 1st, 2017) at all outlets! Online will be available next week. Tickets will be available at @ribbizja @charcoals.flame @jamaicaliquorwarehouse , and all Official Big Wall Ambassadors and are available for a limited time only. V I V A BIG WALL presented by Coca Cola @bigwallparty #bigwallparty #bigwall #finalportofcall #onecaribbean #roadmarchday #carnivalsunday #jamaicacarnival #jamaicacarnival2017 #bacchanal #soca #worldmusic #ladies #costume #fun #sun #rum #rainorshine #funguaranteed #rave #carnival #cocacola #campari #appletonestate',
#   'code': 'BSU82bEhcZN',
#   'comments': {'count': 0},
#   'comments_disabled': False,
#   'date': 1491016672,
#   'dimensions': {'height': 750, 'width': 750},
#   'display_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/e35/17596570_399989587033096_7907501745075388416_n.jpg',
#   'id': '1483077800021050957',
#   'is_video': False,
#   'likes': {'count': 3},
#   'owner': {'id': '30611364'},
#   'thumbnail_src': 'https://scontent-lax3-1.cdninstagram.com/t51.2885-15/s640x640/sh0.08/e35/17596570_399989587033096_7907501745075388416_n.jpg'}]

# %%
[x for x in results if x["is_video"] == True]
# Out:
# []
